# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1  = pd.read_csv( "canada_per_capita_income.csv")
df2   = pd.read_csv( "homeprices.csv")

# %%
from sklearn import linear_model

# %%
df2
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline 
kaka = sns.scatterplot( x = df2['area'] , y = df2['price']  , marker = '+'  , color = "red")  
plt.show()

# %%
reg = linear_model.LinearRegression( )
reg.fit( df2[['area']], df2.price )
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# E:\ttttana\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
ar = pd.read_csv( "areas.csv")

# %%
  predicted = reg.predict( ar )

# %%
predicted
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
ar['prices']  = predicted

# %%
ar
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
ar.to_csv( 'E:/DATA ANLYST/material/prediction.csv' , index = False )

# %%
kaka = sns.scatterplot( x = df2['area'] , y = df2['price']  , marker = '+'  , color = "red")  
plt.plot( df2.area , reg.predict( df2[['area']]) , color = 'b' )
plt.show()
