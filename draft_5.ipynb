# %%
import pandas as pd
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df['ConvertedComp'].median( )
# Out:
# 57287.0

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['Hobbyist'].value_counts( normalize= True )*100
# Out:
# Hobbyist
# Yes    80.169436
# No     19.830564
# Name: proportion, dtype: float64

# %%
df[ ['SocialMedia' ,  'EduOther'  , 'DevType']].head(50)
# Out:
#                          SocialMedia  \
# Respondent
# 1                            Twitter
# 2                          Instagram
# 3                             Reddit
# 4                             Reddit
# 5                           Facebook
# 6                            YouTube
# 7                            YouTube
# 8                            YouTube
# 9                            Twitter
# 10                           YouTube
# 11                               NaN
# 12                            Reddit
# 13                           Twitter
# 14                            Reddit
# 15                           YouTube
# 16                           YouTube
# 17                           YouTube
# 18                     VK ВКонта́кте
# 19                          WhatsApp
# 20                          Facebook
# 21          I don't use social media
# 22                         Instagram
# 23                            Reddit
# 24                            Reddit
# ...

# %%
df['SocialMedia'].value_counts( normalize = True )*100
# Out:
# SocialMedia
# Reddit                      17.023343
# YouTube                     16.379076
# WhatsApp                    15.807051
# Facebook                    15.606902
# Twitter                     13.498822
# Instagram                    7.414996
# I don't use social media     6.577685
# LinkedIn                     5.330602
# WeChat 微信                    0.789938
# Snapchat                     0.743750
# VK ВКонта́кте                0.714142
# Weibo 新浪微博                   0.066322
# Youku Tudou 优酷               0.024871
# Hello                        0.022502
# Name: proportion, dtype: float64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
df['SocialMedia'].head(30)
# Out:
# Respondent
# 1                      Twitter
# 2                    Instagram
# 3                       Reddit
# 4                       Reddit
# 5                     Facebook
# 6                      YouTube
# 7                      YouTube
# 8                      YouTube
# 9                      Twitter
# 10                     YouTube
# 11                         NaN
# 12                      Reddit
# 13                     Twitter
# 14                      Reddit
# 15                     YouTube
# 16                     YouTube
# 17                     YouTube
# 18               VK ВКонта́кте
# 19                    WhatsApp
# 20                    Facebook
# 21    I don't use social media
# 22                   Instagram
# 23                      Reddit
# 24                      Reddit
# 25                     YouTube
# 26    I don't use social media
# 27                     YouTube
# 28                   Instagram
# 29                      Reddit
# ...

# %%
filt = df['Country']  == 'India'
df[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize = True ).loc['China']*100
# Out:
# SocialMedia
# WeChat 微信                   67.054908
# YouTube                      8.818636
# Weibo 新浪微博                   6.988353
# I don't use social media     4.492512
# Twitter                      4.492512
# Reddit                       1.996672
# LinkedIn                     1.830283
# Facebook                     1.331115
# Instagram                    1.164725
# Youku Tudou 优酷               1.164725
# WhatsApp                     0.499168
# VK ВКонта́кте                0.166389
# Name: proportion, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# median salary in germany
# Out:
# 63016.0

# %%
country_grp['ConvertedComp'].agg( [ 'mean' , 'median' , 'max' , 'min' ,'std' ]).loc[ [ 'Canada' , 'Germany'  , 'India']]
# Out:
#                   mean   median        max  min            std
# Country
# Canada   134018.564909  68705.0  2000000.0  0.0  229255.567850
# Germany  109256.884066  63016.0  2000000.0  0.0  187384.595666
# India     28057.664916  10080.0  2000000.0  0.0   85630.003577

# %%
country_grp['ConvertedComp'].loc['Germany']
# Out:
# 63016.0

# %%
 country_grp.get_group(('Germany', ))['ConvertedComp']
# Out:
# Respondent
# 14        57060.0
# 36        20628.0
# 44        87996.0
# 66       137490.0
# 85        52704.0
#            ...
# 64465         NaN
# 71055         NaN
# 75974         NaN
# 80319         NaN
# 83786         NaN
# Name: ConvertedComp, Length: 5866, dtype: float64

# %%
filt = df['Country'] == 'India' 
df.loc[filt, 'LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 36443

# %%
country_grp['LanguageWorkedWith'].apply( lambda x:x.str.contains('Python')).loc['India'].sum()
# Out:
# 3105

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
df['Country']
# Out:
# Respondent
# 1                United Kingdom
# 2        Bosnia and Herzegovina
# 3                      Thailand
# 4                 United States
# 5                       Ukraine
#                   ...
# 88377                    Canada
# 88601                       NaN
# 88802                       NaN
# 88816                       NaN
# 88863                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
country_python = country_grp['LanguageWorkedWith'].apply( lambda x : x.str.contains( 'Python').sum())
country_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
df2 = pd.concat( [country_respondents , country_python] , axis = 'columns' , sort = False )
df2
# Out:
#                    count  LanguageWorkedWith
# Country
# United States      20949               10083
# India               9061                3105
# Germany             5866                2451
# United Kingdom      5737                2384
# Canada              3395                1558
# ...                  ...                 ...
# Tonga                  1                   0
# Timor-Leste            1                   1
# North Korea            1                   0
# Brunei Darussalam      1                   0
# Chad                   1                   0
#
# [179 rows x 2 columns]

# %%
df2.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'} , inplace = True )
df2
# Out:
#                    count  NumKnowsPython
# Country
# United States      20949           10083
# India               9061            3105
# Germany             5866            2451
# United Kingdom      5737            2384
# Canada              3395            1558
# ...                  ...             ...
# Tonga                  1               0
# Timor-Leste            1               1
# North Korea            1               0
# Brunei Darussalam      1               0
# Chad                   1               0
#
# [179 rows x 2 columns]

# %%
df2['percentknowpython'] = ( df2['NumKnowsPython']* 100  / df2['count']) 
df2
# Out:
#                    count  NumKnowsPython  percentknowpython
# Country
# United States      20949           10083          48.131176
# India               9061            3105          34.267741
# Germany             5866            2451          41.783157
# United Kingdom      5737            2384          41.554820
# Canada              3395            1558          45.891016
# ...                  ...             ...                ...
# Tonga                  1               0           0.000000
# Timor-Leste            1               1         100.000000
# North Korea            1               0           0.000000
# Brunei Darussalam      1               0           0.000000
# Chad                   1               0           0.000000
#
# [179 rows x 3 columns]

# %%
df2.sort_values( by = 'percentknowpython'  , ascending = False  )
# Out:
#                                   count  NumKnowsPython  percentknowpython
# Country
# Sao Tome and Principe                 1               1         100.000000
# Timor-Leste                           1               1         100.000000
# Dominica                              1               1         100.000000
# Niger                                 1               1         100.000000
# Turkmenistan                          7               6          85.714286
# ...                                 ...             ...                ...
# Cape Verde                            3               0           0.000000
# Lao People's Democratic Republic      3               0           0.000000
# Malawi                                2               0           0.000000
# Liberia                               2               0           0.000000
# Chad                                  1               0           0.000000
#
# [179 rows x 3 columns]

# %%
df2.loc[  : , "percentknowpython"].sort_values( )
# Out:
# Country
# Chad                       0.000000
# Tajikistan                 0.000000
# Andorra                    0.000000
# Burkina Faso               0.000000
# Cape Verde                 0.000000
#                             ...
# Turkmenistan              85.714286
# Sao Tome and Principe    100.000000
# Niger                    100.000000
# Dominica                 100.000000
# Timor-Leste              100.000000
# Name: percentknowpython, Length: 179, dtype: float64
