# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
print( 'kakaji')
# Out:
# kakaji

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Ayush\data

# %%
import os
print(os.getcwd())  # Check working directory
print(os.listdir())
# Out:
# C:\Users\Ayush\data
# ['.ipynb_checkpoints', 'AmazingMartEU2.xlsx', 'ETH_1h.csv', 'P6-UK-Bank-Customers.csv', 'README_2023.txt', 'so_survey_2023.pdf', 'survey_results_public.csv', 'survey_results_schema.csv', 'titanic_train.csv', 'VNL2023.csv', 'volleyball_project.ipynb']

# %%
df = pd.read_csv('C:/Users/Ayush/data/VNL2023.csv')
df
# Out:
#                           Player    Country  Age  Attack  Block  Serve   Set  \
# 0                  Ichikawa Yuki      Japan   28   15.80   1.13   1.40  0.07
# 1                    Romano Yuri      Italy   26   12.33   1.07   1.47  0.00
# 2               Abdel-Aziz Nimir  Nederland   31   15.33   0.67   2.08  0.00
# 3            Herrera Jaime Jesus       Cuba   28   15.00   0.92   1.75  0.00
# 4                  Takahashi Ran      Japan   22   11.53   0.67   1.00  0.07
# ..                           ...        ...  ...     ...    ...    ...   ...
# 126               Graven Leonard    Germany   19    0.00   0.00   0.00  0.00
# 127                 Balaso Fabio      Italy   28    0.00   0.00   0.00  0.00
# 128      Nacsimento Maique Reis      Brazil   26    0.00   0.00   0.00  0.00
# 129  Garcia Alvarez Yonder Roman       Cuba   30    0.00   0.00   0.00  0.00
# 130              Salparov Teodor   Bulgaria   41    0.00   0.00   0.00  0.00
#
#        Dig  Receive Position
# ...

# %%
df.head()
# Out:
#                 Player    Country  Age  Attack  Block  Serve   Set   Dig  \
# 0        Ichikawa Yuki      Japan   28   15.80   1.13   1.40  0.07  4.80
# 1          Romano Yuri      Italy   26   12.33   1.07   1.47  0.00  3.87
# 2     Abdel-Aziz Nimir  Nederland   31   15.33   0.67   2.08  0.00  3.17
# 3  Herrera Jaime Jesus       Cuba   28   15.00   0.92   1.75  0.00  3.33
# 4        Takahashi Ran      Japan   22   11.53   0.67   1.00  0.07  6.40
#
#    Receive Position
# 0     5.60       OH
# 1     0.00       OP
# 2     0.25       OP
# 3     0.17       OP
# 4     5.07       OH

# %%
df.shape
# Out:
# (131, 10)

# %%
df.describe( )
# Out:
#               Age      Attack       Block       Serve         Set         Dig  \
# count  131.000000  131.000000  131.000000  131.000000  131.000000  131.000000
# mean    27.809160    5.642672    0.845573    0.535802    2.192595    3.428397
# std      4.186268    4.256229    0.700896    0.454346    6.031587    2.077823
# min     19.000000    0.000000    0.000000    0.000000    0.000000    0.530000
# 25%     25.000000    2.800000    0.370000    0.240000    0.000000    1.920000
# 50%     27.000000    5.170000    0.690000    0.420000    0.000000    3.000000
# 75%     30.000000    8.600000    1.140000    0.760000    0.000000    4.510000
# max     41.000000   15.800000    4.080000    2.080000   26.890000   11.440000
#
#           Receive
# count  131.000000
# mean     1.684198
# std      1.989939
# min      0.000000
# 25%      0.000000
# 50%      0.330000
# 75%      3.385000
# max      6.690000

# %%
df.isna().sum()
# Out:
# Player      0
# Country     0
# Age         0
# Attack      0
# Block       0
# Serve       0
# Set         0
# Dig         0
# Receive     0
# Position    0
# dtype: int64

# %%
df.duplicated( ).sum()
# Out:
# 0

# %%
num_cols= df.select_dtypes( include = ['int' , 'float'] ).columns
corr_matrix = df[num_cols].corr() 
print( corr_matrix)
# Out:
#               Age    Attack     Block     Serve       Set       Dig   Receive
# Age      1.000000 -0.177849 -0.101040 -0.108367  0.177757  0.167141 -0.011067
# Attack  -0.177849  1.000000  0.338412  0.768859 -0.430805 -0.098999  0.169892
# Block   -0.101040  0.338412  1.000000  0.335954 -0.132019 -0.348347 -0.265206
# Serve   -0.108367  0.768859  0.335954  1.000000 -0.154815 -0.052501  0.039642
# Set      0.177757 -0.430805 -0.132019 -0.154815  1.000000  0.131659 -0.305869
# Dig      0.167141 -0.098999 -0.348347 -0.052501  0.131659  1.000000  0.624733
# Receive -0.011067  0.169892 -0.265206  0.039642 -0.305869  0.624733  1.000000

# %%
#plt.figure( figsize=( 8 , 8) )
sns.heatmap( corr_matrix, annot = 
            True , cmap= 'coolwarm'  , linewidth = 5 )
plt.title("correlation matrix heatmap") 
plt.show()

# %%
pos_counts= df['Position'].value_counts()
pos_counts
# Out:
# Position
# OH    42
# MB    32
# OP    25
# S     16
# L     16
# Name: count, dtype: int64

# %%
#plt.figure(figsize=(6, 6))  # Adjust figure size
plt.pie(pos_counts, labels=pos_counts.index, autopct='%1.1f%%', startangle= 90)
plt.title('Position Distribution')
plt.show()

# %%
attack_by_country = df.groupby('Country')["Attack"].mean()
attack_by_country.sort_values(ascending = False  , inplace =True  )
attack_by_country
# Out:
# Country
# France       6.670000
# Japan        6.595000
# Cuba         6.344286
# Serbia       5.998750
# Italy        5.965000
# Slovenia     5.961250
# Argentina    5.925000
# Nederland    5.880000
# Poland       5.807000
# Canada       5.405714
# Bulgaria     5.282500
# Brazil       5.250000
# China        5.093750
# Germany      4.833750
# Iran         4.707778
# USA          4.600000
# Name: Attack, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure previous conflicts are removed
plt.figure(figsize=(8, 8))

sns.barplot(x=attack_by_country.index, 
            y=attack_by_country.values, 
           
            legend=False, 
            palette='viridis')

# Correct labels and title
plt.xlabel("Countries")
plt.ylabel("Attack Rate")
plt.title("Attack Average by Country")
plt.xticks(rotation=45)

plt.show()
# Out:
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_87132\896104538.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=attack_by_country.index,

# %%
top_10_countries = attack_by_country.head( 10 )

plt.figure( figsize =( 8 ,6 ))
sns.barplot( x = top_10_countries.index  , y =  top_10_countries.values )
plt.xlabel(  "countries ")
plt.ylabel(" attack rate ")
plt.title( "attack average by country  top 10 ")
# Out:
# Text(0.5, 1.0, 'attack average by country  top 10 ')

# %%
attack_by_country.tail(4 ).plot(kind = "bar")

#plt.title( "attack average by country")
# Out:
# <Axes: xlabel='Country'>

# %%
avg_serve_by_age = df.groupby("Age")["Serve"].mean()  
avg_serve_by_age.sort_values( ascending = False )
# Out:
# Age
# 31    0.910000
# 20    0.880000
# 21    0.770000
# 26    0.681053
# 28    0.667273
# 35    0.666667
# 27    0.662500
# 36    0.660000
# 24    0.640667
# 22    0.534286
# 23    0.526667
# 29    0.477500
# 30    0.429231
# 38    0.400000
# 33    0.321429
# 32    0.290000
# 37    0.270000
# 19    0.200000
# 25    0.165714
# 34    0.026667
# 41    0.000000
# Name: Serve, dtype: float64

# %%
max_attack= df.groupby( [ "Country","Position" ])[ "Attack" ].max().reset_index().sort_values( ascending = False  , by = "Attack").head(20)
max_attack
# Out:
#       Country Position  Attack
# 52      Japan       OH   15.80
# 58  Nederland       OP   15.33
# 33     France       OP   15.25
# 28       Cuba       OP   15.00
# 68     Serbia       OP   14.33
# 12   Bulgaria       OH   14.25
# 22      China       OH   13.50
# 72   Slovenia       OH   12.62
# 8      Brazil       OP   12.46
# 48      Italy       OP   12.33
# 27       Cuba       OH   12.33
# 43       Iran       OP   12.00
# 7      Brazil       OH   11.85
# 2   Argentina       OH   11.62
# 62     Poland       OH   10.57
# 63     Poland       OP   10.57
# 47      Italy       OH   10.45
# 38    Germany       OP   10.42
# 17     Canada       OH    9.75
# 32     France       OH    9.56

# %%
plt.scatter( df["Block"]  ,  df["Receive"]  ,) 
plt.title( "  scatter plot  :  block  vs receive vs  ")
plt.xlabel ( "receive")
plt.ylabel( "block")
# Out:
# Text(0, 0.5, 'block')

# %%
sns.boxplot( x = df["Serve"]  )
# Out:
# <Axes: xlabel='Serve'>

# %%
import numpy as np 
plt.hist( df["Age"]  , bins = 25 , edgecolor = "black")
plt.xticks(np.arange(df["Age"].min(), df["Age"].max() + 1, step=2))  # Adjust step size as needed

plt.title( "histogram of age and values ")
plt.xlabel( " Age ")
plt.ylabel( " frequency ")
# Out:
# Text(0, 0.5, ' frequency ')

# %%
avg_attack_by_position = df.groupby("Position")["Attack"].mean( )
avg_attack_by_position
# Out:
# Position
# L     0.000000
# MB    4.544688
# OH    8.381667
# OP    9.326000
# S     0.536250
# Name: Attack, dtype: float64

# %%
avg_attack_by_position = avg_attack_by_position.sort_values(ascending= True )
#avg_attack_by_position
sns.barplot(  x = avg_attack_by_position.index , y = avg_attack_by_position.values  , palette = "viridis")
# Out:
# C:\Users\Ayush\AppData\Local\Temp\ipykernel_87132\1813718110.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(  x = avg_attack_by_position.index , y = avg_attack_by_position.values  , palette = "viridis")
# <Axes: xlabel='Position'>

# %%
serve_trend_by_age = df.groupby( "Age")["Serve"].mean( ) 
serve_trend_by_age.sort_values(ascending = True )
sns.lineplot( x =serve_trend_by_age.index , y = serve_trend_by_age.values  , marker = 'o'  )
plt.xlabel( "agge in years ")
plt.ylabel ( "average serve rate ")
plt.title( "age vs  serve ")
plt.xticks( range( min( df["Age"]) , max(df["Age"]) +1 , 2 ))
# Out:
# ([<matplotlib.axis.XTick at 0x16d0ec64c50>,
# ...
#  [Text(19, 0, '19'),
#   Text(21, 0, '21'),
#   Text(23, 0, '23'),
#   Text(25, 0, '25'),
#   Text(27, 0, '27'),
#   Text(29, 0, '29'),
#   Text(31, 0, '31'),
#   Text(33, 0, '33'),
#   Text(35, 0, '35'),
#   Text(37, 0, '37'),
#   Text(39, 0, '39'),
#   Text(41, 0, '41')])

# %%
plt
